# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:fef4b02d-0dd1-4978-9883-eeab8d304582.png)

# %% [markdown]
# **_In this notebook, Data Science Tools and Ecosystem are summarized_**

# %% [markdown]
# ![3-intro.png](attachment:74f6baa0-553e-4565-b784-0efd40dba063.png)

# %% [markdown]
# **Objectives:**
# unordered list:
#
#
# * Python
# * R
# * SQL
# * Java
# * Julia
#
# ![10-objectives.png](attachment:dd3d61a4-fd40-4989-beb6-e383cac37268.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia

# %% [markdown]
# ![4-dslanguages.png](attachment:dd9220dc-5a2f-4356-8f5c-ec8a3d3e72ad.png)

# %% [markdown]
#  ### Some of the commonly used libraries used by Data Scientists include:
#
# 1. TensorFlow.
# 2. NumPy.
# 3. SciPy.
# 4. Pandas.
# 5. Matplotlib.
# 6. Keras.

# %% [markdown]
# ![ 5-dslibraries.png](attachment:6db20326-d116-4c4e-a754-c71c21ff5ca0.png)

# %% [markdown]
# # link broken
# Exercise 6 - Create a markdown cell with a table of Data Science tool
# [broken link](https://www.coursera.org/learn/ibm-open-source-tools-for-data-science)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:3282d88c-b60f-4b9a-ae1a-d5a788cd05d9.png)

# %%
(3*4)+5  # This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:36aa038e-1fa4-4836-b80e-d8dfc42b1140.png)

# %%
total_minutes = 200

# This will convert 200 minutes to hours by diving by 60
hours = total_minutes // 60

minutes = total_minutes % 60

time_string = "{}:{}".format(hours, minutes)

print(time_string) # Prints '3:20' in this example
# Out:
# 3:20

# %% [markdown]
# ![9-hourstominutes.png](attachment:4f1dbc80-525f-4fc9-9ba5-fdb5d4ae551f.png)

# %% [markdown]
# ## AUTHOR:
# karam  mansour
